# %% [markdown]
# # File Handling

# %%
'''
1.Text FIle
2.CSB(commma separated Value) File
    -List Data to CSV
    -Dictionary Data to CSV
3.Json(Javascript Object Notation) File
4.Binary File

Operations
-----------
r ->Read
w ->Write
a ->Append
rb ->Read Binary
wb->Write Binary
'''

# %% [markdown]
# ## Text File

# %% [markdown]
# ### Create Text File

# %%
# open(filename,operation)
file=open
