# %% [markdown]
# *1- WAP to input account balance and withdrawal amount and perform transaction.
# Minimum balance must be Rs. 500
# Withdrawal amount must be multiple of 100
# Balance after withdrawal must not be less than 500*

# %%
current_balance=float(input("enter your current balance of your account: "))
withdrawl_amount=float(input("enter your withdrwal balance: "))

if(withdrawl_amount>=500):
    if(current_balance>=500):
        if(withdrawl_amount%100==0):
            remaining_balance=current_balance-withdrawl_amount
            if(current_balance-withdrawl_amount>=0):
                print(f"rs.{withdrwal_amount} amount is withdraw by your account.\n Now your amount is rs.{remaining_balance}")
            else:
                print("not enough balance")
        else:
            print("amount should be the multiple of 100")
    else:
        print("your current balance is less than 500 .Amount should be greater than 500.Thank you")
else:
    print("withdraw amout should be greater than 500")
# Out:
# enter your current balance of your account:  666
# enter your withdrwal balance:  1000
# not enough balance

# %% [markdown]
# **2-WAP to create a simple online shopping bill system.
# Requirements:
# Ask the user to enter the shopping amount.
# Ask whether the customer is a member (yes/no).
# Conditions:
# If the customer is a member:
# Give 20% discount for amount 5000 or more.
# Give 10% discount for amount 2000 or more.
# Otherwise, give 5% discount.
# If the customer is not a member:
# Give 10% discount only if the amount is 5000 or more.
# Otherwise, no discount is given.
# Additional Requirements:
# Calculate 13% VAT on the shopping amount.
# Calculate the final payable amount using:
# Final Amount=Amount+VAT−Discount
# Display:
# Discount
# VAT
# Final Amount.**

# %%
amount=float(input("enter shoping amount"))
has_member=input("do you have memeship \nif have enter :'yes' \nif you dont have enter :'no'\n")
total_amount=0
if (has_member=="yes"):
    if amount>=2000:
        discount_amount=(amount*10)/100
        total_amount=amount-discount_amount
    elif(amount>=5000):
        discount_amount=(amount*20)/100
        total_amount=amount-discount_amount
    elif amount>0 and amount<=2000:
        discount_amount=(amount*5)/100
        total_amount=amount-discount_amount
    else:
        print("invaid amount")
elif(has_member=="no"):
    total_amount=amount
else:
    print("invalid confirmation")
print(f"total amount is = {total_amount}")
# Out:
# enter shoping amount 1000
# do you have memeship
# if have enter :'yes'
# if you dont have enter :'no'
#  yes
# total amount is = 950.0
