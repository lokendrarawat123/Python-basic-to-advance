# %%
import pandas as pd

# %%
df=pd.read_csv('student.csv')
print(df)
# Out:
#        Name  age    address
# 0       Ram   20  Kathmandu
# 1      Hari   40   Lalitpur
# 2      Sita   35  Bhaktapur
# 3      Gita   28  Kathmandu
# 4     Shyam   22   Lalitpur
# 5     Laxmi   45  Bhaktapur
# 6    Bikash   30  Kathmandu
# 7    Aayush   25   Kirtipur
# 8     Pooja   27   Lalitpur
# 9     Suman   33  Kathmandu
# 10    Anish   24  Bhaktapur
# 11     Rina   29     Banepa
# 12    Kiran   31  Kathmandu
# 13  Nirajan   38   Lalitpur
# 14   Sabina   26  Bhaktapur
# 15   Dipesh   42   Kirtipur
# 16   Sunita   36  Kathmandu
# 17   Roshan   23   Lalitpur
# 18   Sarita   48  Bhaktapur
# 19  Aashish   21  Kathmandu

# %%
print(df.head())
# Out:
#     Name  age    address
# 0    Ram   20  Kathmandu
# 1   Hari   40   Lalitpur
# 2   Sita   35  Bhaktapur
# 3   Gita   28  Kathmandu
# 4  Shyam   22   Lalitpur

# %%
print(df.describe())
# Out:
#              age
# count  20.000000
# mean   31.150000
# std     8.228801
# min    20.000000
# 25%    24.750000
# 50%    29.500000
# 75%    36.500000
# max    48.000000

# %%
df=pd.read_csv('student.csv',index_col="Name")
df.iloc[10:15]
# Out:
#          age    address
# Name
# Anish     24  Bhaktapur
# Rina      29     Banepa
# Kiran     31  Kathmandu
# Nirajan   38   Lalitpur
# Sabina    26  Bhaktapur

# %%
df['Hari':'Sunita']
# Out:
#          age    address
# Name
# Hari      40   Lalitpur
# Sita      35  Bhaktapur
# Gita      28  Kathmandu
# Shyam     22   Lalitpur
# Laxmi     45  Bhaktapur
# Bikash    30  Kathmandu
# Aayush    25   Kirtipur
# Pooja     27   Lalitpur
# Suman     33  Kathmandu
# Anish     24  Bhaktapur
# Rina      29     Banepa
# Kiran     31  Kathmandu
# Nirajan   38   Lalitpur
# Sabina    26  Bhaktapur
# Dipesh    42   Kirtipur
# Sunita    36  Kathmandu

# %%
df=pd.read_csv('student.csv',index_col='age')
df=df.sort_index()
df.loc[20:23]
# Out:
#         Name    address
# age
# 20       Ram  Kathmandu
# 21   Aashish  Kathmandu
# 22     Shyam   Lalitpur
# 23    Roshan   Lalitpur

# %%
# import pandas as pd
# df=pd.read_csv('student.csv',index_col="Name")
# print(list(df["Name"]))

# ## print(df["names"].tolist())

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('student.csv')

# %%
plt.plot([1,2,9,4,7])
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.bar(df['Name'],df["age"])
plt.show()
