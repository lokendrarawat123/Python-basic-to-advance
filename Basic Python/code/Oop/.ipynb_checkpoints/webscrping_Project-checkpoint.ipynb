# %%
# from bs4 import BeautifulSoup,MarkupResemblesLocatorWarning
# import warnings,requests
# soup=BeautifulSoup("https://www.worldometers.info/coronavirus/",'html.parser')
# warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.worldometers.info/coronavirus/"

# %%
# 1. Page ko HTML content fetch garne
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
# 2. Page ko HTML text BeautifulSoup ma parse garne
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.title.text)
# Out:
# COVID - Coronavirus Statistics - Worldometer

# %%
# response.text
data=response.text
raw_data=BeautifulSoup(data,'lxml')

# %%
raw_data.title.text
# Out:
# 'COVID - Coronavirus Statistics - Worldometer'

# %%
table_code=raw_data.table

# %%
# table_code

# %%
tags=table_code.find_all('tr')

# %%
# tags

# %%
data_rows=[]
# for tag in tags:
#     print(tag.text)
for tag in tags:
    y=(tag.text).split("\n")
    if y[1] !=' ':
        data_rows.append(y[1:])

# %%
import csv
file=open('covid_data_collection.csv','w',encoding='utf-8')
x=csv.writer(file)
x.writerows(row_data)
file.close()
