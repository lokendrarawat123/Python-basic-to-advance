# %% [markdown]
# ### Encapsulation : it is the process of wrapping data and methods into a single class and restruting direct access to the data

# %%
class Info :
    def __init__(self):
        self.name='Lokenra Rawat'  # public members
        self._age='10'     # protected members 
        self.__salary='10000'    #private members
obj=Info()
print(obj.name)
print(obj._age)
print(obj._Info__salary)
# Out:
# Lokenra Rawat
# 10
# 10000

# %%
class Data:
    def __init__(self,name,age,add):
        self.name=name
        self._add=add
        self.__age=age
    def data(self):
        print(self.name,self._add,self.__age)
class Info(Data):
    def info(self):
        print(self.name,self._add,self._Data__age)
obj=Info("Ram",12,"kathmandu")
obj.data()
obj.info()
# Out:
# Ram kathmandu 12
# Ram kathmandu 12

# %%
class Data:
    def __init__(self,name,age,add):
        self.name=name
        self._add=add
        self.__age=age
    def data(self):
        print(self.name,self._add,self.__age)
    def age_return(self):
        return self.__age
class Info(Data):
    def info(self):
        print(self.name,self._add,super().age_return())
        data=super().age_return()
        print(data)
obj=Info("Ram",12,"kathmandu")
obj.data()
obj.info()
# Out:
# Ram kathmandu 12
# Ram kathmandu 12
# 12

# %%
## Abstraction : Hiding internals details and showinfo only features of a class or objects

# %%
from abc import ABC,abstractmethod
class Car(ABC):
    @abstractmethod
    def drive(self):   # this method is hide also known as abstract.and parebnt class and child class method is should be same
        print(1)

class BMW(Car):
    def drive(self):
        print("Done")
b=BMW()
b.drive()
# Out:
# Done

# %%
# Error Handling

# %%
try:
    # a=int(input('Enter a number: ')
    # b=int(input('Enter a number:b ')
    a=2
    b='2'
    c=[1,2,3,4,5,6]
    print(d)
    print(a/b)
    
except ZeroDivisionError:
    print('Denominator can not be 0')
except ValueError:
    print('Please enter the only number: ')

except TypeError:
    print('two variable data not same')

except IndexError:
    print('Index out of range')
except NameError:
    print('Variavle d is not defined')
except FileNotFoundError:
    print('File not found')  
except ModuleNotFoundError:
    print('Module Not Found')
except AttributeError:
    print('Function method correct')
except SyntaxError:
    print('your santax is incorrect')
except IndentionError:
    print('Correct indention line')
except KeyError:
    print('Key error')
except:
    print("something went wrong")
# Out:
# Variavle d is not defined

# %%
# finally keyword

# %%
file = None
try:
    file=open("../data.text",'r')
    print(file.read())
except FileNotFoundError:                         
    print('file not found')
finally:
    print(file)
    if file:
        file.close()
# Out:
# file not found
# None
