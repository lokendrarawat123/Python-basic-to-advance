# %%
# wap to swap two number without using third variable .
a=int(input("enter a number"))
b=int(input("enter a number"))
print(f"before\n a = {a} b = {b} ")

a=a+b
b=a-b
a=a-b
print("after")
print(f" a = {a} b = {b} ")
# Out:
# enter a number 66
# enter a number 33
# before
#  a = 66 b = 33
# after
#  a = 33 b = 66

# %%
a=445
print("a=",a)
# Out:
# a= 445

# %%
#write a program to swap using third variable
a

# %%
#write a program to convert temperature form celsius to fahrenheit
celsius=int(input("enter the celsius"))
fahrenheit=celsius*9/5+32
print("fahrenheit = ",fahrenheit)
# Out:
# enter the celsius 54
# fahrenheit =  129.2

# %%
# write a program to input a number from the user and display its square and cube.
a=int(input("enter the number"))
square=a**2
cube=a**3
print(f"square of {a} = {square}")
print(f"cube of {a} = {cube}")
# Out:
# enter the number 2
# square of 2 = 4
# cube of 2 = 8

# %%
"""write a program to input 3-digit  number from the user and display
its hundreds ,tens and untits digiits separately."""
a=int(input("enter a three digit number"))
b=a//10
remainder=a%10

unit=remainder
remainder=a%10
tens=b%10
b=b//10
hundred=b

print(f"unit={unit} ,tens={tens},hundred={hundred}")
# Out:
# enter a number 234
# unit=4 ,tens=3,hundred=2
