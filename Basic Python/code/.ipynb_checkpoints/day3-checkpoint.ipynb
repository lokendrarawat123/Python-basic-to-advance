# %%
# day 3 date:2083/4/12

# %%
# data type
a=20
b=20.45 
c="hello"
d=True
e=None
f=2+3j
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# <class 'complex'>

# %%
# type casting
# int(),float(),bool(),str()
print(2+2.5)
print(2+int(2.5))

# %%
a=2
b=2.5
print(int(b))

# %%
print(True+2.5)
print(True+25)

# %%
a="dhjhdf"
b=True
print(bool((bool(a)+b)))
# Out:
# True

# %%
a=25
b="25"
# print(a+b) // error
print(a+int(b))

# %%
a=10
b="ten"
print(a+int(b))
# // error

# %%
a=-2
print(bool(a))

# %%
# if 0 or not a value then return false 
# if variable store any value then return True including space
a=""
print(bool(a))

# %%
# operator 
# arithmetic operator (+,-,/,*,%,**,//)
# Assignment operator (+=,-=,/=,*=,%=,**=,//=)
# relational operatior (<,>,==,<=,>=,!=)
# logical operator(and ,or ,not)


a=25
b="25"
print(a==b)
# Out:
# False

# %%
# first (not) then (and) then (or)
a=1 and not 0 and 0 or 3 or not 4 and 0
print(a)
# Out:
# 3

# %%
#  inpur and output function 
a=input("enter a number")
print(a)
# Out:
# enter a number 4
# 4

# %%
# task 
#  write a program input principal, time, and rate from the user and calculate the simple interest using the formula
time=float(input("enter time in year"))
rate= float(input("enter rate in percent"))
principal=float(input("enter principal"))
simple_intrest=(time*rate*principal)/100
print("total simple intrest =" ,simple_intrest)
# Out:
# enter time 5
# enter rate 5
# enter principal 500
# total simple intrest = 125.0

# %%
#
