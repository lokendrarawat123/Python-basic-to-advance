# %%
# wap to input three sides of a traingle and check whether it is valid or not .if valid ,display its type.
#types:
#equilateral
#isosceles
#scalene
a=int(input("enter length"))
b=int(input("enter length"))
c=int(input("enter length"))
if(a+b>c and a+c>b and b+c>a):
    print("traingle valid")
    if(a==b==c):
        print("equilateral")
    elif(a==b or a==c or b==c):
        print("isosceles")
    else:
        print("scalene")
else:
    print("Not valid")
# Out:
# enter length 4
# enter length 4
# enter length 5
# traingle valid
# isosceles
