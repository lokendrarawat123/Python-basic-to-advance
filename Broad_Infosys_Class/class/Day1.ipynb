# %%
print(3)
# it is method to print some value

# %%
# variable operator value/operand
a=3
b='lokenra'

# %%
# Data Types
'''
1.interger:Numbers->whole number
2.Float:Decimal Numbers
3.Boolean:True/False
4.String:Combination of text,numbers ,specail ,characters->with in single cotaion or double cotaion
5.Complex:3+4j
6.None:Currently Empty
'''

# %%
# Types of Comments
#------------------------
# single line comment --> #
# multiline comment -->''' '''

# my name is lokendra rawat --> this is single line comment
'''
hello 
my name is 
lokendra      -------> this is multiline comment.
rawat
'''
# we can store multi line  comment in variable
# my name is lokendra rawat --> this is single line comment
data= '''
hello 
my name is 
lokendra      -------> this is multiline comment.
rawat
'''
print(data)
# Out:
# '\nhello \nmy name is \nlokendra      -------> this is multiline comment.\nrawat\n'

# %%
# Types of variable format
-------------------------
1.Snake Case--> first_name,last_name,my_name_is_ram
2.Camel Case-->fistName,lastName,myNameIsRam
3.Pascal Case-->FirstName,LastName,MyNameIsRam

# %%
#types of print 
# Employee Details

employee_name='David'
employee_position='Senior'
employee_job_type='Full Time'
employee_salary='30000'
print(employee_name)
print(employee_position)
print(employee_job_type)
print(employee_salary)
# Out:
# David
# Senior
# Full Time
# 30000

# %%
employee_name='David'
employee_position='Senior'
employee_job_type='Full Time'
employee_salary='30000'
print("Employee Name:",employee_name)
print("Employee Position:",employee_position)
print("Employee Job Type:",employee_job_type)
print("Employee Salary:",employee_salary)
# Out:
# Employee Name David
# Employee Position Senior
# Employee Job Type Full Time
# Employee Salary 30000

# %%
# using f-string.  it is used for the concatination and error handling
employee_name='David'
employee_position='Senior'
employee_job_type='Full Time'
employee_salary='30000'
print(f'Employee Name:{employee_name}')
print(f'Employee Position:{employee_position}')
print(f'Employee Job Type:{employee_job_type}')
print(f'Employee Salary:{employee_salary}')
# Out:
# Employee Name:David
# Employee Position:Senior
# Employee Job Type:Full Time
# Employee Salary:30000

# %%
# Escape Sequence 
# \n New line
# \t -Tab or Indent

# %%
# Type Casting
type(employee_name)
type(employee_salary)
# Out:
# str

# %%
value=3.5
type(value)
change_value=int(value)
print(change_value)
print(str(change_value))
print(type(str(change_value)))
# Out:
# 3
# 3
# <class 'str'>
