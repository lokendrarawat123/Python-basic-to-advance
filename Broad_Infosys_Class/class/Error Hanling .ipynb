# %% [markdown]
# # Try Catch in Python

# %%
'''
Exception Handiling
====================
1.Try-Except
2.Else
3.Finallly
4.Raise ->Throws
5.custom exception
'''
try:
    a=int(input('Enter a number'))
    b=int(input('Enter a number'))
    c=a/b
    print(c)
except ValueError as e:
    print(f'Error: Only number values are accepted by input field')
except ZeroDivisionError as e:
    print(f'Error: Number can not divsion by 0 ')

# %%
'''
Exception Handiling
====================
1.Try-Except
2.Else
3.Finallly
4.Raise ->Throws
5.custom exception
'''

# %%
try:
    a=int(input('Enter a number'))
    b=int(input('Enter a number'))
    c=a/b
    print(c)
except ValueError as e:
    print(f'Error: Only number values are accepted by input field')
except ZeroDivisionError as e:
    print(f'Error: Number can not divsion by 0 ')
# Out:
# Enter a number fghd
# Error: Only number values are accepted by input field

# %%
# else: for the only all print  content  of a code:
# finally : if we need to show any how execute program

# %%
try:
    file_name=input('Enter your file name')
    with open(f'{file_name}.txt','r') as file:
        content=file.read()
except FileNotFoundError as e:
    print(f'Error:Given {file_name}.txt doest not exist on file path')
else:
    print(content)
finally:
    print('Program execute succseefully')
# Out:
# Enter your file name gsf
# Error:Given gsf.txt doest not exist on file path
# Program execute succseefully

# %% [markdown]
# # Costum Exception

# %%
age=int(input('Enter your age:'))
if age>18:
    print('You are eligible to vote')
else:
    print('You are not eligible to vote')

# %%
class AgeError(Exception):
    pass

# %%
def checkAge():
    age=int(input('Enter your age:'))
    if age>18:
        print('You are eligible to vote')
    else:
        print('Age Error:You are not eligible to vote')

# %%
try:
    checkAge()
except AgeError as ae:
    print(ae)
except ValueError as ve:
    print('Error: only integer number are accepted')
# Out:
# Enter your age: dfshg
# Error: only integer number are accepted

# %%
class PinError(Exception):
    pass
class Insufficient(Exception):
    pass
class IncorrectAmount(Exception):
    pass

# %%
def atm():
    pin =1234
    balance=50000
    user_pin=int(input('Enter your pin'))
    if user_pin==pin:
        amount=int(input('Enter your withdrawl amount'))
        if amount<balance:
            if amount%1000==0:
                print(f'Rs.{amount} has been withdrawn from A/C no.543263434543')
            else:
                raise IncorrectAmount('Amount Error:Amount must be multiple of 1000')
        else:
            raise Insufficient('Balance Error:withdraw amount must be less than available balance')
    else:
         raise PinError('Pin Error: Incorrect pin')

# %%
try:
    atm()
except PinError as pe:
    print(pe)
except Insufficient as ie:
    print(ie)
except IncorrectAmount as ine:
    print(ine)
except ValueError as e:
    print('Amount must be integer')
# Out:
# Enter your pin 36545
# Pin Error: Incorrect pin

# %% [markdown]
# # Project

# %%
import random

# %%
class DepositAmountError(Exception):
    pass
class WithdrawAmountError(Exception):
    pass
class AccountNotFoundError(Exception):
    pass

# %%
## storage
accounts=[]

# %%
class Bank:
    def __init__(self,name,initial_balance,job_position):
        self.name=name
        self.initial_balance=initial_balance
        self.job_position=job_position
        self.account_number=self.name[1:3]+''.join(str(random.randint(0,9)) for i in range(16))+self.job_position[1:3]
    def depositeAmount(self,amount):
        if amount>100:
            self.initial_balance+=amount
        else:
            raise DepositAmountError('Amount Error: Deposit amount must be more than Rs.100')
    def withdrwaAmount(self,amount):
        if amount <self.initial_balance:
            self.initial_balance-=amount
            print(f'Rs.{amount} has been withdrwan from A/C no.{self.account_number}')
        else:
            raise WithdrawAmountError('Amount Error: Withdraw amount must be less than available balance.')
    def userDetails(self):
        print('User Details')
        print('='*30)
        print(f'Account Holder Name:{self.name}')
        print(f'Account Number : {self.account_number}')
        print(f'Balance Amount : Rs.{self.initial_balance}')
        print(f'Job Position : {self.job_position}')

# %%
# name=input('Enter Your name: ')
# initial_balance=int(input('Enter your initial balance'))
# job_position=input('Enter your job position')

# %%
b=Bank('Shyam',4000,'Developer')
accounts.append(b)
b.userDetails()
# Out:
# User Details
# ...
# Account Holder Name:Shyam
# Account Number : hy2814637137556535ev
# Balance Amount : Rs.4000
# Job Position : Developer

# %%
def findAccountbyAccountNumber(acc_number):
    for account in accounts:
        if account.account_number==acc_number:
            return account
    else:
        raise AccountNotFoundError('Account Number Error: Account not found with given account number does not found.')

# %%
findAccountbyAccountNumber("hy2814637137556535ev")

# %%
while True:
    print('Welcome to Bank Application')
    print('1. Create Account')
    print('2. Deposit Amount')
    print('3. Withdraw Amount')
    print('4. User Details')
    print('5. Exit')

    choice=int(input('Enter your choice: '))
    if choice==1:
        y_n=input('Do you really want to create account(yes/no): ')
        if y_n=='yes':
            print('Create Account')
            
            print('-'*30)
            name=input('Enter account holder name: ')
            balance=int(input('Enter your initial balance: '))
            job=input('Enter your job position: ')
            if balance>100:
                b=Bank(name,balance,job)
                accounts.append(b)
                print(f'Account created with name {name} deposit balance is {balance} with account number {b.account_number}')
            else:
                print('Insufficient deposit balance.Balance must be more than Rs.100')
        else:
            print('Continue with your transaction')
        
    elif choice==2:
        y_n=input('Do you want to deposit amount(yes/no)')
        if y_n=='yes':
            print('Deposit Amount')
            print('-'*30)
            acc_number=input('Enter your account number: ')
            try:
                
                find_acc=findAccountbyAccountNumber(acc_number)
                if find_acc:
                    amount=int(input('Enter your deposit amount'))
                    find_acc.depositeAmount(amount)
            except AccountNotFoundError as anfe:
                print(anfe)
            except DepositAmountError as dae:
                print(dae)
        else:
            print('Continue with your transaction')
            
            
    elif choice==3:
        y_n=input('Do you want to withdraw amount(yes/no)')
        if y_n=='yes':
            print('Withdraw Amount')
            print('-'*30)
            acc_number=input('Enter your account number: ')
            try:
                find_acc=findAccountbyAccountNumber(acc_number)
                if find_acc:
                    amount=int(input('Enter Your withdraw amount'))
                    find_acc.withdrwaAmount(amount)
            except AccountNotFoundError as anfe:
                print(anfe)
            except WithdrawAmountError as wae:
                print(wae)
        else:
            print('Continue with your transaction')
    elif choice==4:
        y_n=input('Do you want to see Your details(yes/no)')
        if y_n=='yes':
            print('User Details')
            acc_number=input('Enter your account number: ')
            try:
                find_acc=findAccountbyAccountNumber(acc_number)
                if find_acc:
                    find_acc.userDetails()
            except AccountNotFoundError as afe:
                print(afe) 
        else:
            print('Continue with your transaction')
    elif choice==5:
        print('Thank you for choosing us')
        break
    else:
        print('Invalid choice.Please choose valid choice')
# Out:
# Welcome to Bank Application
# 1. Create Account
# 2. Deposit Amount
# 3. Withdraw Amount
# 4. User Details
# 5. Exit
# Enter your choice:  3
# Do you want to withdraw amount(yes/no) yes
# Withdraw Amount
# ------------------------------
# Enter your account number:  hy2814637137556535ev
# Enter Your withdraw amount 500000
# Amount Error: Withdraw amount must be less than available balance.
# Welcome to Bank Application
# 1. Create Account
# 2. Deposit Amount
# 3. Withdraw Amount
# 4. User Details
# 5. Exit
# Enter your choice:  3
# Do you want to withdraw amount(yes/no) yes
# Withdraw Amount
# ------------------------------
# Enter your account number:  hy2814637137556535ev
# Enter Your withdraw amount 2000
# Rs.2000 has been withdrwan from A/C no.hy2814637137556535ev
# Welcome to Bank Application
# 1. Create Account
# 2. Deposit Amount
# 3. Withdraw Amount
# 4. User Details
# 5. Exit
